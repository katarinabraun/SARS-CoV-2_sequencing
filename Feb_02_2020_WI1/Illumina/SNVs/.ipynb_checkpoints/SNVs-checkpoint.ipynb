# %% [markdown]
# # Within-host single nucleotide variants
#
# **Date**: 2020-02-17
# **Author**: Katarina Braun
#
#
# ## Overview
# - Look at the frequency of each SNP in each ferret over the course of within-host infections
# - These SNVs were generated with the `Sniffles` pipeline
# - I am going to modify and clean the VCF files generated here and then use them as input for these plots
# - Columns headers of the dataframe will look like this:
#     1. Location
#     2. SNV
#     3. Effect = synonymous or nonsynonymous
#
# **Visualize**:
# One scatterplot per gene where:
# - x axis contains gene length
# - y axis has FREQ
# - datapoints are plotted as closed if nonsynonymous and open if synonymous
#
#
# ## Input:
#
# 1. SNV files in VCF format (output from `Sniffles`) located here:
#     - `SNVs/swab.vcf`
#     - `SNVs/vero76.vcf`
#     - `SNVs/veroE6.vcf`
#     - `SNVs/veroSTAT1KO.vcf`
#
# ## Output:
#
# 1. Cleaned generated from VCF input files will be located here:
#     - `SNVs/cleaned/*`
#
# 2. Spliced data by ferret ID, gene segment, and synonymous vs nonsynonymous will be located here:
#     - `SNVs/by_gene_segment/*`
#
# 3. One plot for index SNPs and one plot for contact SNPs will be found here:
#     - `SNVs/gene_SNVs.pdf`

# %% [markdown]
# ### import modules and dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
import glob
import os
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pathlib import Path
from os.path import splitext
from functools import reduce
from pandas.api.types import is_numeric_dtype
import warnings
from pandas.core.common import SettingWithCopyWarning
from matplotlib.font_manager import FontProperties 
from matplotlib import cm
import itertools
from matplotlib import container
from matplotlib import gridspec
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib.lines as mlines
import matplotlib as mpl

# %% [markdown]
# ## data cleaning

# %% [markdown]
# ### define functions for data cleaning

# %%
# get a list of filenames without the extension from some directory 
# example usage: `get_files('../data_derived/SNV', 'VCFlist')`
def get_files(path): 
    filelist = [os.path.splitext(filename)[0] for filename in os.listdir(path)]
    filelist.remove('.DS_Store')
    return(filelist)
#     print(filelist)

# load all text files in a directory into Pandas dataframes 
# path should be set to path to the text files that you would like to load into dataframes 
# set this function equal to some variable which will then be callable as a list of the dataframes 
# call each dataframe then calling items of the list, the specific sample name can be found within the VCF or dataframe
def load_dataframes(path):
    filelist = [os.path.splitext(file)[0] for file in os.listdir(path) if file.endswith('.vcf')]
    list_of_DFs = []
    for file in filelist: 
        DF = path + '/' + file + '.vcf'
        file = pd.read_csv(DF, header=0, sep='\t', low_memory=False)
        list_of_DFs.append(file)
    print(filelist)
    return(list_of_DFs)

# manipulate SNV dataframes 
# first run load_dataframes and generate a variable for the list of DFs, then feed that variable 
# into this function to clean the dataframe up and save to new CSV 
def clean_dataframes(path, list_of_DFs):
    if not os.path.exists(path + '/cleaned'):
            os.makedirs(path + '/cleaned')
    for DF in list_of_DFs:
        # save the specific animal ID and timepoint to a temporary name = sample 
        sample = DF.columns[9]
        # drop columns that are not needed
        DF.drop(['#CHROM', 'ID', 'QUAL', 'FILTER', 'INFO', 'FORMAT'], axis=1)
        # replace . with "syn" (synonymous SNV) for clarity
        DF['AAchange'] = DF['AAchange'].replace({'.':'syn'})
#         DF['gene'] = DF['gene'].replace({'NA gene':'NA'})
        # create new column with GENE_REF-POS-ALT = SNP
        DF['SNP'] = DF['gene'] + '_' + DF['REF'] + DF['POS'].map(str) + DF['ALT'] + '_' + DF['AAchange']
        # delete rows in the dataframe that contain "not in ORF" -- I don't need to track these SNPs
        DF = DF[~DF['AAchange'].astype(str).str.contains('not in ORF')]
        # reorder the columns to make a little more sense
        DF = DF[['gene', 'POS', 'REF', 'ALT', 'FREQ', 'SNP']]
        # add a column to convert FREQ to % of the population 
        DF['% of population'] = DF['FREQ'].multiply(100)
        # make a cleaned directory if it does not already exist 
        if sample.endswith('_rep2'):
            sample_mod = sample[:-5]
            DF.to_csv(path + '/cleaned/' + sample_mod + '-cleaned.csv', sep='\t')
        else:
            DF.to_csv(path + '/cleaned/' + sample + '-cleaned.csv', sep='\t')

# %% [markdown]
# ### VCF file data-cleaning

# %%
# generate a list of dataframes, loaded from VCF files 
list_of_DFs = load_dataframes('.')
# Out:
# ['veroE6', 'swab', 'vero76', 'veroSTAT1KO']

# %%
# clean up all of the dataframes and save to new CSV files 
clean_dataframes('.', list_of_DFs)

# %%
swab = pd.read_csv('cleaned/swab-cleaned.csv', sep='\t')
vero76 = pd.read_csv('cleaned/vero76-cleaned.csv', sep='\t')
veroE6 = pd.read_csv('cleaned/veroE6-cleaned.csv', sep='\t')
veroSTAT1KO = pd.read_csv('cleaned/veroSTAT1KO-cleaned.csv', sep='\t')

##

# %% [markdown]
# ## slice dataframes into genes and synonymous vs nonsynonymous SNPs

# %% [markdown]
# ### define functions to slice dataframes into genes syn vs nonsyn SNPs

# %%
# slice merged ferret dataframe into individual genes and synonymous and nonsynonymous variants 
# ferret is the merged dataframe from above 
# ferretnum is just a string containing the ferret number, used to make a directory 

DF_slices = ['ORF1a_syn', 'ORF1a_nonsyn', 'ORF1b_syn', 'ORF1b_nonsyn', 'S_syn', 'S_nonsyn', 'ORF3a_syn', 'ORF3a_nonsyn', 'E_syn', 'E_nonsyn', 'M_syn', 'M_nonsyn', 'ORF6_syn', 'ORF6_nonsyn', 'ORF7a_syn', 'ORF7a_nonsyn', 'ORF8_syn', 'ORF8_nonsyn', 'N_syn', 'N_nonsyn', 'ORF10_syn', 'ORF10_nonsyn']
genes = ['ORF1a_', 'ORF1b_', 'S_', 'ORF3a_', 'E_', 'M_', 'ORF6_', 'ORF7a_', 'ORF8_', 'N_', 'ORF10_']
strings = [6, 6, 2, 6, 2, 2, 6, 6, 6, 2, 7]

# genes, strings and path are defined above, this shouldn't be changed
def slice_dataframes(ferret, ferretnum, DF_slices, genes, strings, path):
    if not os.path.exists(path + '/by_gene_segment/' + ferretnum):
            os.makedirs(path + '/by_gene_segment/' + ferretnum)
    DF = ferret
    for DF_slice in DF_slices: 
        DF_slice = pd.DataFrame()
    DF_by_gene = []
    for (gene, string) in zip(genes, strings):
        gene = DF.loc[DF['SNP'].str.contains(gene)]
        if gene.empty:
            pass
        else: 
            gene['SNP'] = gene['SNP'].map(lambda x : str(x)[string:])
            gene['POS'] = gene['SNP'].str.extract('(\d+)')
            gene['POS'] = pd.to_numeric(gene['POS'])
            gene = gene.sort_values(by=['POS'])
            gene = gene.drop(['POS'], axis=1)
        DF_by_gene.append(gene)
#     return(DF_by_gene)
    DF_slices = []
    for (DF, gene) in zip(DF_by_gene, genes): 
        if DF.empty is False:
            DF_syn = DF.loc[DF['SNP'].str.contains("syn")]
            DF_syn['SNP'] = gene + DF_syn['SNP'].astype(str)
            DF_nonsyn = DF.loc[~DF['SNP'].str.contains("syn")]
            DF_nonsyn['SNP'] = gene + DF_nonsyn['SNP'].astype(str)
            # save these dataframes to CSV files
            if DF_syn.empty is False: 
                DF_syn.to_csv(path + '/by_gene_segment/' + ferretnum + '/' + gene + '_syn.csv', sep='\t')
            if DF_nonsyn.empty is False:  
                DF_nonsyn.to_csv(path + '/by_gene_segment/' + ferretnum + '/' + gene + '_nonsyn.csv', sep='\t')
        else: 
            pass
            
### try the if within an if statement thing ... it wasn't working before because I was reutning before I got to that part of the sattemtn!

# %%
# ignore some errors that will pop up 
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# slice all merged ferret dataframes into gene segments as well as synonymous and nonsynonymoust variants 
swab_slices = slice_dataframes(Swab_nCoV_primary, 'Swab_nCoV_primary', DF_slices, genes, strings, '.')
DF_slices = ['ORF1a_syn', 'ORF1a_nonsyn', 'ORF1b_syn', 'ORF1b_nonsyn', 'S_syn', 'S_nonsyn', 'ORF3a_syn', 'ORF3a_nonsyn', 'E_syn', 'E_nonsyn', 'M_syn', 'M_nonsyn', 'ORF6_syn', 'ORF6_nonsyn', 'ORF7a_syn', 'ORF7a_nonsyn', 'ORF8_syn', 'ORF8_nonsyn', 'N_syn', 'N_nonsyn', 'ORF10_syn', 'ORF10_nonsyn']
genes = ['ORF1a_', 'ORF1b_', 'S_', 'ORF3a_', 'E_', 'M_', 'ORF6_', 'ORF7a_', 'ORF8_', 'N_', 'ORF10_']
strings = [6, 6, 2, 6, 2, 2, 6, 6, 6, 2, 7]

V1_slices = slice_dataframes(nCoV_V1, 'nCoV_V1', DF_slices, genes, strings, '.')
DF_slices = ['ORF1a_syn', 'ORF1a_nonsyn', 'ORF1b_syn', 'ORF1b_nonsyn', 'S_syn', 'S_nonsyn', 'ORF3a_syn', 'ORF3a_nonsyn', 'E_syn', 'E_nonsyn', 'M_syn', 'M_nonsyn', 'ORF6_syn', 'ORF6_nonsyn', 'ORF7a_syn', 'ORF7a_nonsyn', 'ORF8_syn', 'ORF8_nonsyn', 'N_syn', 'N_nonsyn', 'ORF10_syn', 'ORF10_nonsyn']
genes = ['ORF1a_', 'ORF1b_', 'S_', 'ORF3a_', 'E_', 'M_', 'ORF6_', 'ORF7a_', 'ORF8_', 'N_', 'ORF10_']
strings = [6, 6, 2, 6, 2, 2, 6, 6, 6, 2, 7]

V2_slices = slice_dataframes(nCoV_V2, 'nCoV_V2', DF_slices, genes, strings, '.')
DF_slices = ['ORF1a_syn', 'ORF1a_nonsyn', 'ORF1b_syn', 'ORF1b_nonsyn', 'S_syn', 'S_nonsyn', 'ORF3a_syn', 'ORF3a_nonsyn', 'E_syn', 'E_nonsyn', 'M_syn', 'M_nonsyn', 'ORF6_syn', 'ORF6_nonsyn', 'ORF7a_syn', 'ORF7a_nonsyn', 'ORF8_syn', 'ORF8_nonsyn', 'N_syn', 'N_nonsyn', 'ORF10_syn', 'ORF10_nonsyn']
genes = ['ORF1a_', 'ORF1b_', 'S_', 'ORF3a_', 'E_', 'M_', 'ORF6_', 'ORF7a_', 'ORF8_', 'N_', 'ORF10_']
strings = [6, 6, 2, 6, 2, 2, 6, 6, 6, 2, 7]

V3_slices = slice_dataframes(nCoV_V3, 'nCoV_V3', DF_slices, genes, strings, '.')
DF_slices = ['ORF1a_syn', 'ORF1a_nonsyn', 'ORF1b_syn', 'ORF1b_nonsyn', 'S_syn', 'S_nonsyn', 'ORF3a_syn', 'ORF3a_nonsyn', 'E_syn', 'E_nonsyn', 'M_syn', 'M_nonsyn', 'ORF6_syn', 'ORF6_nonsyn', 'ORF7a_syn', 'ORF7a_nonsyn', 'ORF8_syn', 'ORF8_nonsyn', 'N_syn', 'N_nonsyn', 'ORF10_syn', 'ORF10_nonsyn']
genes = ['ORF1a_', 'ORF1b_', 'S_', 'ORF3a_', 'E_', 'M_', 'ORF6_', 'ORF7a_', 'ORF8_', 'N_', 'ORF10_']
strings = [6, 6, 2, 6, 2, 2, 6, 6, 6, 2, 7]


###

# %% [markdown]
# ### load individual genes into dataframes (swab)

# %%
swab_syn_ORF1a = pd.read_csv('by_gene_segment/swab/ORF1a__syn.csv', header=0, sep='\t', low_memory=False)
swab_syn_ORF1a['loc'] = swab_syn_ORF1a['SNP'].str.split('_').str[1]
swab_syn_ORF1a['loc'] = swab_syn_ORF1a['loc'].str.extract('(\d+)').astype(int)
swab_syn_ORF1a = swab_syn_ORF1a.sort_values('loc')

swab_nonsyn_ORF1a = pd.read_csv('by_gene_segment/swab/ORF1a__nonsyn.csv', header=0, sep='\t', low_memory=False)
swab_nonsyn_ORF1a['loc'] = swab_nonsyn_ORF1a['SNP'].str.split('_').str[1]
swab_nonsyn_ORF1a['loc'] = swab_nonsyn_ORF1a['loc'].str.extract('(\d+)').astype(int)
swab_nonsyn_ORF1a = swab_nonsyn_ORF1a.sort_values('loc')

swab_syn_ORF1b = pd.read_csv('by_gene_segment/swab/ORF1b__syn.csv', header=0, sep='\t', low_memory=False)
swab_syn_ORF1b['loc'] = swab_syn_ORF1b['SNP'].str.split('_').str[1]
swab_syn_ORF1b['loc'] = swab_syn_ORF1b['loc'].str.extract('(\d+)').astype(int)
swab_syn_ORF1b = swab_syn_ORF1b.sort_values('loc')

swab_nonsyn_ORF1b = pd.read_csv('by_gene_segment/swab/ORF1b__nonsyn.csv', header=0, sep='\t', low_memory=False)
swab_nonsyn_ORF1b['loc'] = swab_nonsyn_ORF1b['SNP'].str.split('_').str[1]
swab_nonsyn_ORF1b['loc'] = swab_nonsyn_ORF1b['loc'].str.extract('(\d+)').astype(int)
swab_nonsyn_ORF1b = swab_nonsyn_ORF1b.sort_values('loc')

swab_syn_N = pd.read_csv('by_gene_segment/swab/N__syn.csv', header=0, sep='\t', low_memory=False)
swab_syn_N['loc'] = swab_syn_N['SNP'].str.split('_').str[1]
swab_syn_N['loc'] = swab_syn_N['loc'].str.extract('(\d+)').astype(int)
swab_syn_N = swab_syn_N.sort_values('loc')

##

# %% [markdown]
# ### VERO 1

# %%
vero76_syn_ORF1a = pd.read_csv('by_gene_segment/vero76/ORF1a__syn.csv', header=0, sep='\t', low_memory=False)
vero76_syn_ORF1a['loc'] = vero76_syn_ORF1a['SNP'].str.split('_').str[1]
vero76_syn_ORF1a['loc'] = vero76_syn_ORF1a['loc'].str.extract('(\d+)').astype(int)
vero76_syn_ORF1a = vero76_syn_ORF1a.sort_values('loc')

vero76_nonsyn_ORF1a = pd.read_csv('by_gene_segment/vero76/ORF1a__nonsyn.csv', header=0, sep='\t', low_memory=False)
vero76_nonsyn_ORF1a['loc'] = vero76_nonsyn_ORF1a['SNP'].str.split('_').str[1]
vero76_nonsyn_ORF1a['loc'] = vero76_nonsyn_ORF1a['loc'].str.extract('(\d+)').astype(int)
vero76_nonsyn_ORF1a = vero76_nonsyn_ORF1a.sort_values('loc')

vero76_syn_ORF1b = pd.read_csv('by_gene_segment/vero76/ORF1b__syn.csv', header=0, sep='\t', low_memory=False)
vero76_syn_ORF1b['loc'] = vero76_syn_ORF1b['SNP'].str.split('_').str[1]
vero76_syn_ORF1b['loc'] = vero76_syn_ORF1b['loc'].str.extract('(\d+)').astype(int)
vero76_syn_ORF1b = vero76_syn_ORF1b.sort_values('loc')

vero76_nonsyn_ORF1b = pd.read_csv('by_gene_segment/vero76/ORF1b__nonsyn.csv', header=0, sep='\t', low_memory=False)
vero76_nonsyn_ORF1b['loc'] = vero76_nonsyn_ORF1b['SNP'].str.split('_').str[1]
vero76_nonsyn_ORF1b['loc'] = vero76_nonsyn_ORF1b['loc'].str.extract('(\d+)').astype(int)
vero76_nonsyn_ORF1b = vero76_nonsyn_ORF1b.sort_values('loc')

vero76_nonsyn_ORF3a = pd.read_csv('by_gene_segment/vero76/ORF3a__nonsyn.csv', header=0, sep='\t', low_memory=False)
vero76_nonsyn_ORF3a['loc'] = vero76_nonsyn_ORF3a['SNP'].str.split('_').str[1]
vero76_nonsyn_ORF3a['loc'] = vero76_nonsyn_ORF3a['loc'].str.extract('(\d+)').astype(int)
vero76_nonsyn_ORF3a = vero76_nonsyn_ORF3a.sort_values('loc')

vero76_syn_ORF7a = pd.read_csv('by_gene_segment/vero76/ORF7a__syn.csv', header=0, sep='\t', low_memory=False)
vero76_syn_ORF7a['loc'] = vero76_syn_ORF7a['SNP'].str.split('_').str[1]
vero76_syn_ORF7a['loc'] = vero76_syn_ORF7a['loc'].str.extract('(\d+)').astype(int)
vero76_syn_ORF7a = vero76_syn_ORF7a.sort_values('loc')

vero76_nonsyn_ORF7a = pd.read_csv('by_gene_segment/vero76/ORF7a__nonsyn.csv', header=0, sep='\t', low_memory=False)
vero76_nonsyn_ORF7a['loc'] = vero76_nonsyn_ORF7a['SNP'].str.split('_').str[1]
vero76_nonsyn_ORF7a['loc'] = vero76_nonsyn_ORF7a['loc'].str.extract('(\d+)').astype(int)
vero76_nonsyn_ORF7a = vero76_nonsyn_ORF7a.sort_values('loc')

vero76_syn_S = pd.read_csv('by_gene_segment/vero76/S__syn.csv', header=0, sep='\t', low_memory=False)
vero76_syn_S['loc'] = vero76_syn_S['SNP'].str.split('_').str[1]
vero76_syn_S['loc'] = vero76_syn_S['loc'].str.extract('(\d+)').astype(int)
vero76_syn_S = vero76_syn_S.sort_values('loc')

vero76_nonsyn_S = pd.read_csv('by_gene_segment/vero76/S__nonsyn.csv', header=0, sep='\t', low_memory=False)
vero76_nonsyn_S['loc'] = vero76_nonsyn_S['SNP'].str.split('_').str[1]
vero76_nonsyn_S['loc'] = vero76_nonsyn_S['loc'].str.extract('(\d+)').astype(int)
vero76_nonsyn_S = vero76_nonsyn_S.sort_values('loc')

vero76_nonsyn_ORF10 = pd.read_csv('by_gene_segment/vero76/ORF10__nonsyn.csv', header=0, sep='\t', low_memory=False)
vero76_nonsyn_ORF10['loc'] = vero76_nonsyn_ORF10['SNP'].str.split('_').str[1]
vero76_nonsyn_ORF10['loc'] = vero76_nonsyn_ORF10['loc'].str.extract('(\d+)').astype(int)
vero76_nonsyn_ORF10 = vero76_nonsyn_ORF10.sort_values('loc')

##

# %% [markdown]
# ### VERO 2

# %%
veroE6_syn_ORF1a = pd.read_csv('by_gene_segment/veroE6/ORF1a__syn.csv', header=0, sep='\t', low_memory=False)
veroE6_syn_ORF1a['loc'] = veroE6_syn_ORF1a['SNP'].str.split('_').str[1]
veroE6_syn_ORF1a['loc'] = veroE6_syn_ORF1a['loc'].str.extract('(\d+)').astype(int)
veroE6_syn_ORF1a = veroE6_syn_ORF1a.sort_values('loc')

veroE6_nonsyn_ORF1a = pd.read_csv('by_gene_segment/veroE6/ORF1a__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroE6_nonsyn_ORF1a['loc'] = veroE6_nonsyn_ORF1a['SNP'].str.split('_').str[1]
veroE6_nonsyn_ORF1a['loc'] = veroE6_nonsyn_ORF1a['loc'].str.extract('(\d+)').astype(int)
veroE6_nonsyn_ORF1a = veroE6_nonsyn_ORF1a.sort_values('loc')

veroE6_nonsyn_ORF1b = pd.read_csv('by_gene_segment/veroE6/ORF1b__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroE6_nonsyn_ORF1b['loc'] = veroE6_nonsyn_ORF1b['SNP'].str.split('_').str[1]
veroE6_nonsyn_ORF1b['loc'] = veroE6_nonsyn_ORF1b['loc'].str.extract('(\d+)').astype(int)
veroE6_nonsyn_ORF1b = veroE6_nonsyn_ORF1b.sort_values('loc')

veroE6_nonsyn_E = pd.read_csv('by_gene_segment/veroE6/E__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroE6_nonsyn_E['loc'] = veroE6_nonsyn_E['SNP'].str.split('_').str[1]
veroE6_nonsyn_E['loc'] = veroE6_nonsyn_E['loc'].str.extract('(\d+)').astype(int)
veroE6_nonsyn_E = veroE6_nonsyn_E.sort_values('loc')

veroE6_syn_ORF3a = pd.read_csv('by_gene_segment/veroE6/ORF3a__syn.csv', header=0, sep='\t', low_memory=False)
veroE6_syn_ORF3a['loc'] = veroE6_syn_ORF3a['SNP'].str.split('_').str[1]
veroE6_syn_ORF3a['loc'] = veroE6_syn_ORF3a['loc'].str.extract('(\d+)').astype(int)
veroE6_syn_ORF13a = veroE6_syn_ORF3a.sort_values('loc')

veroE6_syn_ORF7a = pd.read_csv('by_gene_segment/veroE6/ORF7a__syn.csv', header=0, sep='\t', low_memory=False)
veroE6_syn_ORF7a['loc'] = veroE6_syn_ORF7a['SNP'].str.split('_').str[1]
veroE6_syn_ORF7a['loc'] = veroE6_syn_ORF7a['loc'].str.extract('(\d+)').astype(int)
veroE6_syn_ORF7a = veroE6_syn_ORF7a.sort_values('loc')

veroE6_nonsyn_ORF7a = pd.read_csv('by_gene_segment/veroE6/ORF7a__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroE6_nonsyn_ORF7a['loc'] = veroE6_nonsyn_ORF7a['SNP'].str.split('_').str[1]
veroE6_nonsyn_ORF7a['loc'] = veroE6_nonsyn_ORF7a['loc'].str.extract('(\d+)').astype(int)
veroE6_nonsyn_ORF7a = veroE6_nonsyn_ORF7a.sort_values('loc')

veroE6_nonsyn_S = pd.read_csv('by_gene_segment/veroE6/S__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroE6_nonsyn_S['loc'] = veroE6_nonsyn_S['SNP'].str.split('_').str[1]
veroE6_nonsyn_S['loc'] = veroE6_nonsyn_S['loc'].str.extract('(\d+)').astype(int)
veroE6_nonsyn_S = veroE6_nonsyn_S.sort_values('loc')
#

# %% [markdown]
# ### VERO 3

# %%
veroSTAT1KO_syn_ORF1a = pd.read_csv('by_gene_segment/veroSTAT1KO/ORF1a__syn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_syn_ORF1a['loc'] = veroSTAT1KO_syn_ORF1a['SNP'].str.split('_').str[1]
veroSTAT1KO_syn_ORF1a['loc'] = veroSTAT1KO_syn_ORF1a['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_syn_ORF1a = veroSTAT1KO_syn_ORF1a.sort_values('loc')

veroSTAT1KO_nonsyn_ORF1a = pd.read_csv('by_gene_segment/veroSTAT1KO/ORF1a__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_nonsyn_ORF1a['loc'] = veroSTAT1KO_nonsyn_ORF1a['SNP'].str.split('_').str[1]
veroSTAT1KO_nonsyn_ORF1a['loc'] = veroSTAT1KO_nonsyn_ORF1a['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_nonsyn_ORF1a = veroSTAT1KO_nonsyn_ORF1a.sort_values('loc')

veroSTAT1KO_syn_ORF1b = pd.read_csv('by_gene_segment/veroSTAT1KO/ORF1b__syn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_syn_ORF1b['loc'] = veroSTAT1KO_syn_ORF1b['SNP'].str.split('_').str[1]
veroSTAT1KO_syn_ORF1b['loc'] = veroSTAT1KO_syn_ORF1b['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_syn_ORF1b = veroSTAT1KO_syn_ORF1b.sort_values('loc')

veroSTAT1KO_nonsyn_ORF1b = pd.read_csv('by_gene_segment/veroSTAT1KO/ORF1b__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_nonsyn_ORF1b['loc'] = veroSTAT1KO_nonsyn_ORF1b['SNP'].str.split('_').str[1]
veroSTAT1KO_nonsyn_ORF1b['loc'] = veroSTAT1KO_nonsyn_ORF1b['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_nonsyn_ORF1b = veroSTAT1KO_nonsyn_ORF1b.sort_values('loc')

veroSTAT1KO_nonsyn_ORF3a = pd.read_csv('by_gene_segment/veroSTAT1KO/ORF3a__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_nonsyn_ORF3a['loc'] = veroSTAT1KO_nonsyn_ORF3a['SNP'].str.split('_').str[1]
veroSTAT1KO_nonsyn_ORF3a['loc'] = veroSTAT1KO_nonsyn_ORF3a['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_nonsyn_ORF3a = veroSTAT1KO_nonsyn_ORF3a.sort_values('loc')

veroSTAT1KO_syn_ORF7a = pd.read_csv('by_gene_segment/veroSTAT1KO/ORF7a__syn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_syn_ORF7a['loc'] = veroSTAT1KO_syn_ORF7a['SNP'].str.split('_').str[1]
veroSTAT1KO_syn_ORF7a['loc'] = veroSTAT1KO_syn_ORF7a['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_syn_ORF7a = veroSTAT1KO_syn_ORF7a.sort_values('loc')

veroSTAT1KO_nonsyn_ORF7a = pd.read_csv('by_gene_segment/veroSTAT1KO/ORF7a__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_nonsyn_ORF7a['loc'] = veroSTAT1KO_nonsyn_ORF7a['SNP'].str.split('_').str[1]
veroSTAT1KO_nonsyn_ORF7a['loc'] = veroSTAT1KO_nonsyn_ORF7a['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_nonsyn_ORF7a = veroSTAT1KO_nonsyn_ORF7a.sort_values('loc')

veroSTAT1KO_syn_S = pd.read_csv('by_gene_segment/veroSTAT1KO/S__syn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_syn_S['loc'] = veroSTAT1KO_syn_S['SNP'].str.split('_').str[1]
veroSTAT1KO_syn_S['loc'] = veroSTAT1KO_syn_S['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_syn_S = veroSTAT1KO_syn_S.sort_values('loc')

veroSTAT1KO_nonsyn_S = pd.read_csv('by_gene_segment/veroSTAT1KO/S__nonsyn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_nonsyn_S['loc'] = veroSTAT1KO_nonsyn_S['SNP'].str.split('_').str[1]
veroSTAT1KO_nonsyn_S['loc'] = veroSTAT1KO_nonsyn_S['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_nonsyn_S = veroSTAT1KO_nonsyn_S.sort_values('loc')

veroSTAT1KO_syn_E = pd.read_csv('by_gene_segment/veroSTAT1KO/E__syn.csv', header=0, sep='\t', low_memory=False)
veroSTAT1KO_syn_E ['loc'] = veroSTAT1KO_syn_E ['SNP'].str.split('_').str[1]
veroSTAT1KO_syn_E['loc'] = veroSTAT1KO_syn_E['loc'].str.extract('(\d+)').astype(int)
veroSTAT1KO_syn_E = veroSTAT1KO_syn_E.sort_values('loc')

#

# %% [markdown]
# ## generate one plot per gene segment:
#
# X: SNV frequency
# Y: gene position

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #ORF1a

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# ORF1a (ax1) 
ax1.set_title('ORF1a', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,14000)
ax1.set_xticks([0, 3000, 6000, 9000, 12000])
ax1.scatter(x=swab_syn_ORF1a['loc'], y=swab_syn_ORF1a['% of population'], marker='o', facecolors='none', edgecolors=swab)
ax1.scatter(x=swab_nonsyn_ORF1a['loc'], y=swab_nonsyn_ORF1a['% of population'], marker='o', facecolors=swab, edgecolors=swab)
ax1.scatter(x=vero76_syn_ORF1a['loc'], y=vero76_syn_ORF1a['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
ax1.scatter(x=vero76_nonsyn_ORF1a['loc'], y=vero76_nonsyn_ORF1a['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
ax1.scatter(x=veroE6_syn_ORF1a['loc'], y=veroE6_syn_ORF1a['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
ax1.scatter(x=veroE6_nonsyn_ORF1a['loc'], y=veroE6_nonsyn_ORF1a['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
ax1.scatter(x=veroSTAT1KO_syn_ORF1a['loc'], y=veroSTAT1KO_syn_ORF1a['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
ax1.scatter(x=veroSTAT1KO_nonsyn_ORF1a['loc'], y=veroSTAT1KO_nonsyn_ORF1a['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')

fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("ORF1a_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #ORF1b

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# ORF1b (ax1) 
ax1.set_title('ORF1b', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,8000)
ax1.set_xticks([0, 2000, 4000, 6000, 8000])
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='vero 1, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='vero 1, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='vero 2, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='vero 2, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='vero 3, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='vero 3, nonsynonymous SNVs')

fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("ORF1b_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #S

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# S (ax1) 
ax1.set_title('Spike', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,4000)
ax1.set_xticks([0, 1000, 2000, 3000, 4000])
ax1.scatter(x=vero76_syn_S['loc'], y=vero76_syn_S['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
ax1.scatter(x=vero76_nonsyn_S['loc'], y=vero76_nonsyn_S['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
ax1.scatter(x=veroE6_nonsyn_S['loc'], y=veroE6_nonsyn_S['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
ax1.scatter(x=veroSTAT1KO_syn_S['loc'], y=veroSTAT1KO_syn_S['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
ax1.scatter(x=veroSTAT1KO_nonsyn_S['loc'], y=veroSTAT1KO_nonsyn_S['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)
# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("S_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #ORF3a

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# ORF3a (ax1) 
ax1.set_title('ORF3a', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,1000)
ax1.set_xticks([0, 250, 500, 750, 1000])
# ax1.scatter(x=swab_syn_ORF3a['loc'], y=swab_syn_ORF3a['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_ORF3a['loc'], y=swab_nonsyn_ORF3a['% of population'], marker='o', facecolors=swab, edgecolors=swab)
# ax1.scatter(x=vero76_syn_ORF3a['loc'], y=vero76_syn_ORF3a['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
ax1.scatter(x=vero76_nonsyn_ORF3a['loc'], y=vero76_nonsyn_ORF3a['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
ax1.scatter(x=veroE6_syn_ORF3a['loc'], y=veroE6_syn_ORF3a['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
# ax1.scatter(x=veroE6_nonsyn_ORF3a['loc'], y=veroE6_nonsyn_ORF3a['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
# ax1.scatter(x=veroSTAT1KO_syn_ORF3a['loc'], y=veroSTAT1KO_syn_ORF3a['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
ax1.scatter(x=veroSTAT1KO_nonsyn_ORF3a['loc'], y=veroSTAT1KO_nonsyn_ORF3a['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)
# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("ORF3a_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #E

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# E (ax1) 
ax1.set_title('E', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,500)
ax1.set_xticks([0, 250, 500])
# ax1.scatter(x=swab_syn_E['loc'], y=swab_syn_E['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_E['loc'], y=swab_nonsyn_E['% of population'], marker='o', facecolors=swab, edgecolors=swab)
# ax1.scatter(x=vero76_syn_E['loc'], y=vero76_syn_E['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
# ax1.scatter(x=vero76_nonsyn_E['loc'], y=vero76_nonsyn_E['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
# ax1.scatter(x=veroE6_syn_E['loc'], y=veroE6_syn_E['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
ax1.scatter(x=veroE6_nonsyn_E['loc'], y=veroE6_nonsyn_E['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
ax1.scatter(x=veroSTAT1KO_syn_E['loc'], y=veroSTAT1KO_syn_E['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
# ax1.scatter(x=veroSTAT1KO_nonsyn_E['loc'], y=veroSTAT1KO_nonsyn_E['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("E_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #M

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# M (ax1) 
ax1.set_title('M', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,1000)
ax1.set_xticks([0, 250, 500, 1000])
# ax1.scatter(x=swab_syn_M['loc'], y=swab_syn_M['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_M['loc'], y=swab_nonsyn_M['% of population'], marker='o', facecolors=swab, edgecolors=swab)
# ax1.scatter(x=vero76_syn_M['loc'], y=vero76_syn_M['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
# ax1.scatter(x=vero76_nonsyn_M['loc'], y=vero76_nonsyn_M['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
# ax1.scatter(x=veroE6_syn_M['loc'], y=veroE6_syn_M['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
# ax1.scatter(x=veroE6_nonsyn_M['loc'], y=veroE6_nonsyn_M['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
# ax1.scatter(x=veroSTAT1KO_syn_M['loc'], y=veroSTAT1KO_syn_M['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
# ax1.scatter(x=veroSTAT1KO_nonsyn_M['loc'], y=veroSTAT1KO_nonsyn_M['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("M_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #ORF6

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# ORF6 (ax1) 
ax1.set_title('ORF6', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,500)
ax1.set_xticks([0, 250, 500])
# ax1.scatter(x=swab_syn_ORF6['loc'], y=swab_syn_ORF6['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_ORF6['loc'], y=swab_nonsyn_ORF6['% of population'], marker='o', facecolors=swab, edgecolors=swab)
# ax1.scatter(x=vero76_syn_ORF6['loc'], y=vero76_syn_ORF6['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
# ax1.scatter(x=vero76_nonsyn_ORF6['loc'], y=vero76_nonsyn_ORF6['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
# ax1.scatter(x=veroE6_syn_ORF6['loc'], y=veroE6_syn_ORF6['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
# ax1.scatter(x=veroE6_nonsyn_ORF6['loc'], y=veroE6_nonsyn_ORF6['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
# ax1.scatter(x=veroSTAT1KO_syn_ORF6['loc'], y=veroSTAT1KO_syn_ORF6['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
# ax1.scatter(x=veroSTAT1KO_nonsyn_ORF6['loc'], y=veroSTAT1KO_nonsyn_ORF6['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("ORF6_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #ORF7a

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# ORF7a (ax1) 
ax1.set_title('ORF7a', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,500)
ax1.set_xticks([0, 250, 500])
# ax1.scatter(x=swab_syn_ORF7a['loc'], y=swab_syn_ORF7a['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_ORF7a['loc'], y=swab_nonsyn_ORF7a['% of population'], marker='o', facecolors=swab, edgecolors=swab)
ax1.scatter(x=vero76_syn_ORF7a['loc'], y=vero76_syn_ORF7a['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
ax1.scatter(x=vero76_nonsyn_ORF7a['loc'], y=vero76_nonsyn_ORF7a['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
ax1.scatter(x=veroE6_syn_ORF7a['loc'], y=veroE6_syn_ORF7a['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
ax1.scatter(x=veroE6_nonsyn_ORF7a['loc'], y=veroE6_nonsyn_ORF7a['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
ax1.scatter(x=veroSTAT1KO_syn_ORF7a['loc'], y=veroSTAT1KO_syn_ORF7a['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
ax1.scatter(x=veroSTAT1KO_nonsyn_ORF7a['loc'], y=veroSTAT1KO_nonsyn_ORF7a['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("ORF7a_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #ORF8

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# ORF8 (ax1) 
ax1.set_title('ORF8', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,500)
ax1.set_xticks([0, 250, 500])
# ax1.scatter(x=swab_syn_ORF8['loc'], y=swab_syn_ORF8['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_ORF8['loc'], y=swab_nonsyn_ORF8['% of population'], marker='o', facecolors=swab, edgecolors=swab)
# ax1.scatter(x=vero76_syn_ORF8['loc'], y=vero76_syn_ORF8['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
# ax1.scatter(x=vero76_nonsyn_ORF8['loc'], y=vero76_nonsyn_ORF8['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
# ax1.scatter(x=veroE6_syn_ORF8['loc'], y=veroE6_syn_ORF8['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
# ax1.scatter(x=veroE6_nonsyn_ORF8['loc'], y=veroE6_nonsyn_ORF8['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
# ax1.scatter(x=veroSTAT1KO_syn_ORF8['loc'], y=veroSTAT1KO_syn_ORF8['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
# ax1.scatter(x=veroSTAT1KO_nonsyn_ORF8['loc'], y=veroSTAT1KO_nonsyn_ORF8['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("ORF8_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #N

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# N (ax1) 
ax1.set_title('N', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,1500)
ax1.set_xticks([0, 500, 1000, 1500])
ax1.scatter(x=swab_syn_N['loc'], y=swab_syn_N['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_N['loc'], y=swab_nonsyn_N['% of population'], marker='o', facecolors=swab, edgecolors=swab)
# ax1.scatter(x=vero76_syn_N['loc'], y=vero76_syn_N['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
# ax1.scatter(x=vero76_nonsyn_N['loc'], y=vero76_nonsyn_N['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
# ax1.scatter(x=veroE6_syn_N['loc'], y=veroE6_syn_N['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
# ax1.scatter(x=veroE6_nonsyn_N['loc'], y=veroE6_nonsyn_N['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
# ax1.scatter(x=veroSTAT1KO_syn_N['loc'], y=veroSTAT1KO_syn_N['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
# ax1.scatter(x=veroSTAT1KO_nonsyn_N['loc'], y=veroSTAT1KO_nonsyn_N['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("N_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
# define hex colors
swab = '#F18F01'
vero_76 = '#5EA304'
vero_E6 = '#007BA9'
vero_STAT1KO = '#23B5D3'

# generate a figure with sub-plots (one for each gene segment)
fig = plt.figure(figsize=(8,4), facecolor='w')
plt.style.use('default')
mpl.rc('font', family='Arial')
gs = gridspec.GridSpec(1, 6)

ax1 = fig.add_subplot(gs[0,0:6]) #ORF10

# get right of top and right frame of each subplot
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(True)
ax1.spines['left'].set_visible(True)
    
# set fontsize of axes 
ax1.tick_params(axis = 'both', which = 'major', labelsize = 10)
ax1.tick_params(axis = 'both', which = 'minor', labelsize = 10)

# ORF10 (ax1) 
ax1.set_title('ORF10', fontname='Arial', fontsize=14)
ax1.set_facecolor('white')
for tick in ax1.get_xticklabels():
    tick.set_fontname("Arial")
for tick in ax1.get_yticklabels():
    tick.set_fontname("Arial")
ax1.set_ylim(-5,50)
ax1.set_xlim(-5,500)
ax1.set_xticks([0, 250, 500])
# ax1.scatter(x=swab_syn_ORF10['loc'], y=swab_syn_ORF10['% of population'], marker='o', facecolors='none', edgecolors=swab)
# ax1.scatter(x=swab_nonsyn_ORF10['loc'], y=swab_nonsyn_ORF10['% of population'], marker='o', facecolors=swab, edgecolors=swab)
# ax1.scatter(x=vero76_syn_ORF10['loc'], y=vero76_syn_ORF10['% of population'], marker='^', facecolors='none', edgecolors=vero_76)
ax1.scatter(x=vero76_nonsyn_ORF10['loc'], y=vero76_nonsyn_ORF10['% of population'], marker='^', facecolors=vero_76, edgecolors=vero_76)
# ax1.scatter(x=veroE6_syn_ORF10['loc'], y=veroE6_syn_ORF10['% of population'], marker='s', facecolors='none', edgecolors=vero_E6)
# ax1.scatter(x=veroE6_nonsyn_ORF10['loc'], y=veroE6_nonsyn_ORF10['% of population'], marker='s', facecolors=vero_E6, edgecolors=vero_E6)
# ax1.scatter(x=veroSTAT1KO_syn_ORF10['loc'], y=veroSTAT1KO_syn_ORF10['% of population'], marker='d', facecolors='none', edgecolors=vero_STAT1KO)
# ax1.scatter(x=veroSTAT1KO_nonsyn_ORF10['loc'], y=veroSTAT1KO_nonsyn_ORF10['% of population'], marker='d', facecolors=vero_STAT1KO, edgecolors=vero_STAT1KO)

# add a common x axis label for the entire figure 
fig.text(-0.015, 0.5, 'SNV frequency (%)', va='center', rotation='vertical', fontsize=14, fontname='Arial')

# add a legend to this plot
swab_syn = mlines.Line2D([], [], marker='o', markerfacecolor='None', markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, synonymous SNVs')
swab_nonsyn = mlines.Line2D([], [], marker='o', markerfacecolor=swab, markeredgecolor=swab, linestyle='None', markersize=10, label='clinical swab, nonsynonymous SNVs')
vero76_syn = mlines.Line2D([], [], marker='^', markerfacecolor='None', markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 76, synonymous SNVs')
vero76_nonsyn = mlines.Line2D([], [], marker='^', markerfacecolor=vero_76, markeredgecolor=vero_76, linestyle='None', markersize=10, label='Vero 761, nonsynonymous SNVs')
veroE6_syn = mlines.Line2D([], [], marker='s', markerfacecolor='None', markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, synonymous SNVs')
veroE6_nonsyn = mlines.Line2D([], [], marker='s', markerfacecolor=vero_E6, markeredgecolor=vero_E6, linestyle='None', markersize=10, label='Vero E6, nonsynonymous SNVs')
veroSTAT1KO_syn = mlines.Line2D([], [], marker='d', markerfacecolor='None', markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, synonymous SNVs')
veroSTAT1KO_nonsyn = mlines.Line2D([], [], marker='d', markerfacecolor=vero_STAT1KO, markeredgecolor=vero_STAT1KO, linestyle='None', markersize=10, label='Vero STAT-1 KO, nonsynonymous SNVs')
fig.legend(handles=[swab_syn, swab_nonsyn, vero76_syn, vero76_nonsyn, veroE6_syn, veroE6_nonsyn, veroSTAT1KO_syn, veroSTAT1KO_nonsyn], frameon=False, fontsize=14, bbox_to_anchor=(1.45,0.9))

# use tight_layout to optimize spacing of axes and titles within each subplot
fig.tight_layout()
fig.show()

# save this plot to the figures folder 
fig.savefig("ORF10_snvs.pdf", bbox_inches='tight', dpi=300)
# Out:
# /Users/katbraun/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
